# %% [markdown]
# # Productivity Model Training
#
# Reproducible entry point for Phase 2 productivity regression training.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path('..').resolve()
sys.path.insert(0, str(PROJECT_ROOT))

from src.models.train_phase2_models import train_phase2

train_phase2(PROJECT_ROOT)

# %% [markdown]
# Outputs are written to `models/productivity_model.joblib` and `reports/productivity_model_report.md`.
